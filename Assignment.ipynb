# %%
# Importing Libraries in the Titanic Dataset

import numpy as np
import pandas as pd
# matplotlib is used for visualization
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Reading the dataset using pandas
titanic_train = pd.read_csv('train.csv')
titanic_test = pd.read_csv('test.csv')

# %%
# Titanic Train first 5 columns ko dekhne ke liye
# We can see more columns by increasing the number in the brackets
titanic_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Exploratory Data Analysis (EDA)

# SibSp is the number of siblings or spouses aboard
# Parch is the number of parents or children aboard
# Embarked is the port of embarkation means kis port se ship me chade the
# Pclass is the passenger class
# Name is the name of the passenger
# Cabin is the cabin number of the passenger
# Ticket is the ticket number of the passenger
# Fare is the amount of money spent on the ticket
# Age is the age of the passenger
# Survived is the target variable i.e. whether the passenger survived or not (0 means the passenger did not survive and 1 means the passenger survived) which we have to predict.

# %%
# How many rows and columns are there in the Titanic Train dataset

titanic_train.shape

# 891 rows and 12 columns are there in the Titanic Train dataset
# Out:
# (891, 12)

# %%
# How many nan values are there in the Titanic Train dataset

titanic_train.isnull()

# false means there is no nan value and true means there is nan value on that particular place
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
# Count unique values in the Titanic Train dataset particular column

titanic_train['Survived'].value_counts()

# 0 means the passenger did not survive and 1 means the passenger survived
# 549 passengers did not survive and 342 passengers survived
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
list(titanic_train['Survived'].value_counts())
# Out:
# [549, 342]

# %%
list(titanic_train['Survived'].value_counts().keys())
# Out:
# [0, 1]

# %%
# figure size of the Titanic Train dataset

# Creating a bar plot of the Titanic Train dataset
# titanic_train['Survived'].value_counts() will give the count of 0 and 1 in the Survived column in the Titanic Train dataset and then we will plot the bar plot of the count of 0 and 1 in the Survived column in the Titanic Train dataset using plt.bar() function
# value_counts() function gives the count of unique values in the column like in the Survived column there are 2 unique values 0 and 1 so it will give the count of 0 and 1 in the Survived column
# keys() function gives the unique values in the column like in the Survived column there are 2 unique values 0 and 1 so it will give the unique values 0 and 1 in the Survived column
# list() function converts the pandas series into the list
# plt.bar() function is used to plot the bar plot
# plt.bar() in which the first argument is the values of the x-axis and the second argument is the values of the y-axis 
plt.bar(list(titanic_train['Survived'].value_counts().keys()), list(titanic_train['Survived'].value_counts()), color=['purple', 'green'])
plt.xlabel('Survived')
plt.ylabel('Count')
plt.title('Count of Survived')
# plt.show() function is used to display the plot it will display without this function also but it will show some extra information in the output
plt.show()

# %%
titanic_train['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
plt.bar(list(titanic_train['Pclass'].value_counts().keys()), list(titanic_train['Pclass'].value_counts()), color=['purple', 'red', 'green'])
# Out:
# <BarContainer object of 3 artists>

# %%
titanic_train['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
plt.bar(list(titanic_train['Sex'].value_counts().keys()), list(titanic_train['Sex'].value_counts()), color=['purple', 'red'])
plt.title('Count of Male and Females')
plt.show()

# %%
titanic_train['SibSp'].value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
plt.bar(list(titanic_train['SibSp'].value_counts().keys()), list(titanic_train['SibSp'].value_counts()), color=['purple', 'red', 'green', 'blue', 'yellow', 'black', 'pink'])
plt.title('Count of SibSp')
plt.show()

# %%
titanic_train['Age'].value_counts()
# Out:
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %%
# plt.bar(list(titanic_train['Age'].value_counts().keys()), list(titanic_train['Age'].value_counts()))
# We will not do this for age as age is a continuous variable and it will give a lot of bars in the bar plot so we will use the histogram for the age column
plt.hist(titanic_train['Age'] , color='purple' , edgecolor='black')
# edgecolor is used to give the color to the edges of the bars in the histogram
plt.title('Age Histogram')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
# Set background of the plot
plt.style.use('ggplot')
plt.hist(titanic_train['Fare'] , color='purple' , edgecolor='black')
plt.title('Fare Histogram')
plt.xlabel('Fare')
plt.ylabel('Count')
plt.show()

# %%
titanic_train['Parch'].value_counts()
# Out:
# Parch
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64

# %%
plt.bar(list(titanic_train['Parch'].value_counts().keys()), list(titanic_train['Parch'].value_counts()) , color=['purple', 'red', 'green', 'blue'])
plt.xlabel('Parch')
plt.ylabel('Count')
plt.title('Count of Parch')
plt.show()

# %%
list(titanic_train['Embarked'].value_counts().keys())
# Out:
# ['S', 'C', 'Q']

# %%
list(titanic_train['Embarked'].value_counts())
# Out:
# [644, 168, 77]

# %%
plt.bar(list(titanic_train['Embarked'].value_counts().keys()), list(titanic_train['Embarked'].value_counts()), color=['purple', 'red', 'green'])
plt.xlabel('Embarked')
plt.ylabel('Count')
plt.title('Count of Embarked')
plt.show()

# %%
sum(titanic_train['PassengerId'].isnull())
# There are 0 nan values in the Passenger Id column
# Out:
# 0

# %%
sum(titanic_train['Survived'].isnull())
# There are 0 nan values in the Survived column
# Out:
# 0

# %%
sum(titanic_train['Pclass'].isnull())
# Out:
# 0

# %%
sum(titanic_train['Name'].isnull())
# Out:
# 0

# %%
sum(titanic_train['Sex'].isnull())
# Out:
# 0

# %%
sum(titanic_train['Age'].isnull())
# There are 177 nan values in the Age column
# Out:
# 177

# %%
sum(titanic_train['SibSp'].isnull())
# Out:
# 0

# %%
sum(titanic_train['Parch'].isnull())
# Out:
# 0

# %%
sum(titanic_train['Ticket'].isnull())
# Out:
# 0

# %%
sum(titanic_train['Fare'].isnull())
# Out:
# 0

# %%
sum(titanic_train['Cabin'].isnull())
# Out:
# 687

# %%
sum(titanic_train['Embarked'].isnull())
# Out:
# 2

# %%
titanic_train = titanic_train.dropna()
# This will drop all the rows which have nan values in any of the columns in the Titanic Train dataset

# %%
titanic_train.shape
# Out:
# (183, 12)

# %%
# Pehle 891 rows and 12 columns the ab 183 rows and 12 columns hai Titanic Train dataset me removing all the null value rows resulting 0 nan values in the Titanic Train dataset
sum(titanic_train['Cabin'].isnull())

# inplace=True means the changes will be made in the original dataset and not in the copy of the dataset which is made by default
# by default inplace=False
# Out:
# 0

# %%
sum(titanic_train['Age'].isnull())
# Out:
# 0

# %%
titanic_train.isnull().sum()

# This will show the count of nan values in each column in the Titanic Train dataset
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
titanic_train['Age'].describe()

# This will give the count, mean, standard deviation, minimum, 25%, 50%, 75%, and maximum values of the Age column in the Titanic Train dataset
# Out:
# count    183.000000
# mean      35.674426
# std       15.643866
# min        0.920000
# 25%       24.000000
# 50%       36.000000
# 75%       47.500000
# max       80.000000
# Name: Age, dtype: float64

# %%
plt.scatter(titanic_train['Age'], titanic_train['Fare'], color='purple')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.title('Age vs Fare')
plt.show()

# This will plot the scatter plot between Age and Fare column in the Titanic Train dataset shpwing how much fare is given by the passengers of different ages

# %%
# Regression is used to predict the continuous values like in the above plot we can predict the fare of the passengers of different ages using regression
# Linear Regression is used to predict the continuous values
# Logistic Regression is used to predict the categorical values like in the Titanic Train dataset we have to predict whether the passenger survived or not which is a categorical value
# in simple words, Logistic Regression is used for values which are in the form of 0 and 1 like in the Titanic Train dataset we have to predict whether the passenger survived or not which is in the form of 0 and 1
# and Linear Regression is used for values which are in the form of continuous values like in the above plot we have to predict the fare of the passengers of different ages which is a continuous value

# %%
titanic_train.columns

# This will give the names of all the columns in the Titanic Train dataset
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic_train.describe()

# This will give the count, mean, standard deviation, minimum, 25%, 50%, 75%, and maximum values of all the columns in the Titanic Train dataset
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   183.000000  183.000000  183.000000  183.000000  183.000000
# mean    455.366120    0.672131    1.191257   35.674426    0.464481
# std     247.052476    0.470725    0.515187   15.643866    0.644159
# min       2.000000    0.000000    1.000000    0.920000    0.000000
# 25%     263.500000    0.000000    1.000000   24.000000    0.000000
# 50%     457.000000    1.000000    1.000000   36.000000    0.000000
# 75%     676.000000    1.000000    1.000000   47.500000    1.000000
# max     890.000000    1.000000    3.000000   80.000000    3.000000
#
#             Parch        Fare
# count  183.000000  183.000000
# mean     0.475410   78.682469
# std      0.754617   76.347843
# min      0.000000    0.000000
# 25%      0.000000   29.700000
# 50%      0.000000   57.000000
# 75%      1.000000   90.000000
# max      4.000000  512.329200

# %%
titanic_train['Age']

# This will give the Age column in the Titanic Train dataset
# Out:
# 1      38.0
# 3      35.0
# 6      54.0
# 10      4.0
# 11     58.0
#        ...
# 871    47.0
# 872    33.0
# 879    56.0
# 887    19.0
# 889    26.0
# Name: Age, Length: 183, dtype: float64

# %%
titanic_train['Age'].mean()

# Mean of the Age column in the Titanic Train dataset
# Out:
# 35.6744262295082

# %%
titanic_train['Age'].fillna(titanic_train['Age'].mean(), inplace=True)

# %%
titanic_train['Age'].isna().sum()
# Out:
# 0

# %%
titanic_train.fillna({'Cabin': titanic_train['Cabin'].mode()[0]}, inplace=True)

# This will fill the nan values in the Cabin column with the mode of the Cabin column in the Titanic Train dataset
# .mode()[0] will give the most frequent value in the Cabin column and [0] is used to get the value only and not the count of the value which is given by mode() function
# inplace=True means the changes will be made in the original dataset and not in the copy of the dataset which is made by default

# %%
titanic_train['Cabin'].isna().sum()
# Out:
# 0

# %%
titanic_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare    Cabin Embarked
# 0      0         A/5 21171   7.2500  B96 B98        S
# 1      0          PC 17599  71.2833      C85        C
# 2      0  STON/O2. 3101282   7.9250  B96 B98        S
# 3      0            113803  53.1000     C123        S
# ...

# %%
titanic_train.groupby(['Sex','Survived']).size().plot(kind='barh')
plt.xlabel('Count of Passengers')
plt.ylabel('Male And Female Survived')

plt.show()

# First we will group the Sex and Survived column in the Titanic Train dataset and then we will plot the bar plot of the grouped dataset
# .size() function is used to get the count of the grouped dataset and then we will plot the bar plot of the grouped dataset using .plot(kind='barh') function
# kind='barh' is used to plot the horizontal bar plot

# %%
titanic_train['Family'] = titanic_train['SibSp'] + titanic_train['Parch']+1

# Creating a new column Family in the Titanic Train dataset by adding the SibSp and Parch column and then adding 1 to the sum of SibSp and Parch column
# Adding 1 to the sum of SibSp and Parch column because the passenger himself is also a part of the family
# Parch is the number of parents or children aboard and SibSp is the number of siblings or spouses aboard

# %%
titanic_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare    Cabin Embarked  Family
# 0      0         A/5 21171   7.2500  B96 B98        S       2
# 1      0          PC 17599  71.2833      C85        C       2
# 2      0  STON/O2. 3101282   7.9250  B96 B98        S       1
# 3      0            113803  53.1000     C123        S       2
# ...

# %%
# Categorical Columns are the columns which have a limited number of unique values like in the Titanic Train dataset :
# Survived column has 2 unique values 0 and 1
# Pclass column has 3 unique values
# Sex column has 2 unique values
# SibSp column has 7 unique values
# Parch column has 7 unique values
# Embarked column has 3 unique values

# Numerical Columns are the columns which have continuous values like in the Titanic Train dataset :
# Age column has continuous values
# Fare column has continuous values
# PassengerId column has continuous values

# Mixed Columns are the columns which have both continuous and categorical values like in the Titanic Train dataset :
# Name column has both continuous and categorical values
# Cabin column has both continuous and categorical values
# Ticket column has both continuous and categorical values

titanic_train.tail()
# last 5 rows of the Titanic Train dataset
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare    Cabin Embarked  Family
# 886    male  27.0      0      0      211536  13.00  B96 B98        S       1
# 887  female  19.0      0      0      112053  30.00      B42        S       1
# 888  female   NaN      1      2  W./C. 6607  23.45  B96 B98        S       4
# 889    male  26.0      0      0      111369  30.00     C148        C       1
# 890    male  32.0      0      0      370376   7.75  B96 B98        Q       1

# %%
titanic_train.isnull().sum()

# Shows the count of nan values in each column in the Titanic Train dataset
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin            0
# Embarked         2
# Family           0
# dtype: int64

# %%
titanic_train.duplicated().sum()

# Shows the count of duplicate rows in the Titanic Train dataset
# Out:
# 0

# %%
plt.title('Percentage of Survived')
plt.pie(titanic_train['Survived'].value_counts(), colors=['red', 'green'])
plt.legend(['Not Survived', 'Survived'])
plt.show()

# %%
titanic_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Removing all the columns which are not required in the Titanic Train dataset
titanic_train = titanic_train.drop(['PassengerId', 'Name', 'Ticket', 'Cabin'], axis=1)
# axis=1 means we are dropping the columns and not the rows

# %%
titanic_train.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
titanic_train.groupby(['Pclass','Survived']).size().plot(kind='barh')
plt.xlabel('Passenger Class')
plt.ylabel('Male And Female Survived')

plt.show()

# %%
titanic_train.groupby(['Age','Survived']).size().plot(kind='hist')
plt.xlabel('Age')
plt.ylabel('Male And Female Survived')

plt.show()

# %%
titanic_train.groupby(['Family','Survived']).size().plot(kind='barh')
plt.xlabel('Family')
plt.ylabel('Male And Female Survived')

plt.show()

# (11, 0) means 11 passengers were there in the family and all of them did not survive

# %%
titanic_train.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Embarked      2
# Family        0
# dtype: int64

# %%
titanic_train.dtypes

# int64 means the column has integer values
# float64 means the column has float values
# object means the column has string values
# int64 means discrete values and float64 means continuous values and object means categorical values
# Out:
# Survived      int64
# Pclass        int64
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Fare        float64
# Embarked     object
# Family        int64
# dtype: object

# %%
sns.heatmap(titanic_train.isnull(),yticklabels=False)

# Visualizing cleaned data using heatmap
# sns.heatmap() function is used to plot the heatmap of the dataset
# heatmap is used to show the nan values in the dataset in the form of colors
# yellow color shows the nan values in the dataset
# yticklabels=False is used to remove the y-axis labels means the column names in the heatmap
# titanic_train.isnull() is used to get the nan values in the dataset and then we will plot the heatmap of the nan values in the dataset using sns.heatmap() function
# Out:
# <Axes: >

# %%
titanic_train[titanic_train['Fare'] == 53.1000]
# This will give the row in which the Fare column has the value 53.1000
# Out:
#      PassengerId  Survived  Pclass  \
# 3              4         1       1
# 137          138         0       1
# 724          725         1       1
# 748          749         0       1
# 809          810         1       1
#
#                                                Name     Sex   Age  SibSp  \
# 3      Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 137                     Futrelle, Mr. Jacques Heath    male  37.0      1
# 724                   Chambers, Mr. Norman Campbell    male  27.0      1
# 748                       Marvin, Mr. Daniel Warner    male  19.0      1
# 809  Chambers, Mrs. Norman Campbell (Bertha Griggs)  female  33.0      1
#
#      Parch  Ticket  Fare Cabin Embarked
# 3        0  113803  53.1  C123        S
# 137      0  113803  53.1  C123        S
# 724      0  113806  53.1    E8        S
# 748      0  113773  53.1   D30        S
# 809      0  113806  53.1    E8        S

# %%
sns.countplot(x = 'Sex', hue = 'Survived' , data = titanic_train)
# hue is used to differentiate the Survived column on the basis of its unique values like in the Survived column there are 2 unique values 0 and 1 so it will differentiate the Survived column on the basis of 0 and 1
# x is the column name which we want to plot on the x-axis and data is the dataset name
plt.title('Count Plot')
# Out:
# Text(0.5, 1.0, 'Count Plot')

# %%
# Creates a cross-tabulation or contingency table b/w Sex and Survived columns
# normalize='columns' is used to get the percentage of the values in the column 
sns.heatmap(pd.crosstab(titanic_train['Survived'],titanic_train['Sex'],normalize='columns')*100)
# Out:
# <Axes: xlabel='Sex', ylabel='Survived'>

# %%
# Remove columns with string values
numeric_columns = titanic_train.select_dtypes(include=['int64', 'float64']).columns
correlation_matrix = titanic_train[numeric_columns].corr()

# Plot the correlation matrix
sns.heatmap(correlation_matrix)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(25,25))
sns.countplot(y = 'Cabin', data = titanic_train)
# Out:
# <Axes: xlabel='count', ylabel='Cabin'>

# %%
# totals

pd.crosstab(index = titanic_train['Sex'], columns = titanic_train['Survived'] , margins = True)
# Out:
# Survived    0    1  All
# Sex
# female     81  233  314
# male      468  109  577
# All       549  342  891

# %%
pd.crosstab(index = titanic_train['Sex'], columns = titanic_train['Survived'])

# tabular represntation
# Out:
# Survived    0    1
# Sex
# female     81  233
# male      468  109

# %%
# box plot means the minimum, 25%, 50%, 75%, and maximum values of the column
# 50% means the median of the column
# 25% means the 25th percentile of the column
# 75% means the 75th percentile of the column

sns.boxplot(x = 'SibSp', data = titanic_train)
plt.title('Box Plot of SibSp')
# Out:
# Text(0.5, 1.0, 'Box Plot of SibSp')

# %%
# Analysis Report

titanic_train=pd.get_dummies(titanic_train)

# get_dummies() function is used to convert the categorical values into numerical values
# we are converting the categorical values into numerical values because the machine learning model only understands the numerical values and then when we see head of the dataset we will see the new columns created by the get_dummies() function for the categorical values in the dataset

# %%
titanic_train.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare  \
# 0            1         0       3  22.0      1      0   7.2500
# 1            2         1       1  38.0      1      0  71.2833
# 2            3         1       3  26.0      0      0   7.9250
# 3            4         1       1  35.0      1      0  53.1000
# 4            5         0       3  35.0      0      0   8.0500
#
#    Name_Abbing, Mr. Anthony  Name_Abbott, Mr. Rossmore Edward  \
# 0                     False                             False
# 1                     False                             False
# 2                     False                             False
# 3                     False                             False
# 4                     False                             False
#
#    Name_Abbott, Mrs. Stanton (Rosa Hunt)  ...  Cabin_F G73  Cabin_F2  \
# 0                                  False  ...        False     False
# 1                                  False  ...        False     False
# ...

# %%
# pairplot is used to plot pairwise relationships in a dataset like in the below plot we have plotted the pairwise relationships between the Fare, Age, Pclass, and Survived columns in the Titanic Train dataset
# 

sns.pairplot(titanic_train[["Fare","Age","Pclass","Survived"]],vars = ["Fare","Age","Pclass"],hue="Survived", dropna=True,markers=["o", "s"])
plt.title('Pair Plot')
# Out:
# Text(0.5, 1.0, 'Pair Plot')
